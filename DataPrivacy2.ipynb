# %% [markdown]
# <a href="https://colab.research.google.com/github/AMRISMA/DataScience/blob/master/DataPrivacy2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Datasets used: ['WA_Fn-UseC_-HR-Employee-Attrition.csv' and 'Mall_Customers.csv']

##-------Generalization of categorical data-----------

# Import Required packages
import pandas as pd 
import numpy as np
import scipy.stats
hr = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
df = pd.DataFrame(hr)

# %%
# See the dataset
hr.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
##-----------Explore the distribution-----------------
# Show the absolute frequencies of each unique value
hr['EducationField'].value_counts()

# Generate a bar plot for the categories
df['BusinessTravel'].value_counts().plot(kind='bar')

# %%
df['EducationField'].value_counts().plot(kind='bar')

# %%
# Obtain the absolute frequencies of each unique value
counts = hr['EducationField'].value_counts()

# Print the list of indexes
print(counts.index)
# Out:
# Index(['Life Sciences', 'Medical', 'Marketing', 'Technical Degree', 'Other',
#        'Human Resources'],
#       dtype='object')

# %%
# Probability distributions of each unique value
counts = df['EducationField'].value_counts(normalize=True)
counts
# Out:
# Life Sciences       0.412245
# Medical             0.315646
# Marketing           0.108163
# Technical Degree    0.089796
# Other               0.055782
# Human Resources     0.018367
# Name: EducationField, dtype: float64

# %%
# Values of the frequencies of each unique value
df['EducationField'].value_counts(normalize=True).values
# Out:
# array([0.4122449 , 0.31564626, 0.10816327, 0.08979592, 0.05578231,
#        0.01836735])

# %%
##------------Sampling from the same distribution----------

hr_sample = pd.DataFrame(hr)
# Sample from a probability distribution
hr_sample['EducationField']= np.random.choice(counts.index, p=counts.values,size=len(hr))

# See resulting dataset
hr.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2      Marketing              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
# Show the absolute frequencies of each category
hr['EducationField'].value_counts()
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
# Show the frequencies of the resulting column
hr_sample['EducationField'].value_counts()
# Out:
# Life Sciences       563
# Medical             495
# Marketing           155
# Technical Degree    139
# Other                96
# Human Resources      22
# Name: EducationField, dtype: int64

# %%
###Lets practice with HR datasets
## See the dataset
hr.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2      Marketing              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
import matplotlib.pyplot as plt
x = hr.Age
plt.hist(x)
# Out:
# (array([ 57., 105., 224., 265., 255., 217., 131.,  92.,  77.,  47.]),
#  array([18. , 22.2, 26.4, 30.6, 34.8, 39. , 43.2, 47.4, 51.6, 55.8, 60. ]),
#  <a list of 10 Patch objects>)

# %%
##------------Applying a distribution----------------
import scipy.stats

# Fit the genlogistic distribution to the continuous variable Age
params = scipy.stats.genlogistic.fit(hr['Age'])

# See the parameters of the continuous functions
print(params)
# Out:
# (4.9899067653418285, 22.32808853181744, 7.046590524738551)

# %%
##----Sampling from the continuous distribution-----

# Sample from the genlogistic distribution
df['Age'] = scipy.stats.genlogistic.rvs(size=len(df.index), *params)

# See the resulting dataset
df['Age'].head()
# Out:
# 0    33.000575
# 1    41.844666
# 2    38.517323
# 3    37.503574
# 4    39.153281
# Name: Age, dtype: float64

# %%
# Round the values to obtain discrete values
Rounded_discrete_values = df['Age'] = df['Age'].round()
Rounded_discrete_values
# Out:
# 0       33.0
# 1       42.0
# 2       39.0
# 3       38.0
# 4       39.0
#         ...
# 1465    61.0
# 1466    49.0
# 1467    32.0
# 1468    28.0
# 1469    31.0
# Name: Age, Length: 1470, dtype: float64

# %%
x = Rounded_discrete_values
plt.hist(x)
# Out:
# (array([ 30., 216., 485., 393., 193.,  92.,  45.,  10.,   3.,   3.]),
#  array([15., 22., 29., 36., 43., 50., 57., 64., 71., 78., 85.]),
#  <a list of 10 Patch objects>)

# %%
##------------K-anonymity-------------------
# Explore DataFrame
hr.head()
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0  33.0       Yes      Travel_Rarely       1102                   Sales
# 1  42.0        No  Travel_Frequently        279  Research & Development
# 2  39.0       Yes      Travel_Rarely       1373  Research & Development
# 3  38.0        No  Travel_Frequently       1392  Research & Development
# 4  39.0        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
##----------Exploring unique combination of quasi-identifiers---------
# Calculate how many unique combinations are for Age and Department
hr.groupby(['Age','Department']).size().reset_index(name='Count')
# Out:
#      Age              Department  Count
# 0     18  Research & Development      5
# 1     18                   Sales      3
# 2     19         Human Resources      1
# 3     19  Research & Development      5
# 4     19                   Sales      3
# ..   ...                     ...    ...
# 110   59         Human Resources      2
# 111   59  Research & Development      4
# 112   59                   Sales      4
# 113   60  Research & Development      2
# 114   60                   Sales      3
#
# [115 rows x 3 columns]

# %%
##--------------Approach: generalization------------------
# Generalize Age by creating 4 groups of intervals
hr['Age_group'] = pd.cut(hr['Age'], bins=4)

# Explore the dataset with intervals
hr.head()
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0  33.0       Yes      Travel_Rarely       1102                   Sales
# 1  42.0        No  Travel_Frequently        279  Research & Development
# 2  39.0       Yes      Travel_Rarely       1373  Research & Development
# 3  38.0        No  Travel_Frequently       1392  Research & Development
# 4  39.0        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  StandardHours StockOptionLevel  TotalWorkingYears  \
# 0  ...             80                0                  8
# 1  ...             80                1                 10
# 2  ...             80                0                  7
# 3  ...             80                0                  8
# 4  ...             80                1                  6
#
#    TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                      0                1              6                   4
# 1                      3                3             10                   7
# 2                      3                3              0                   0
# 3                      3                3              8                   7
# 4                      3                3              2                   2
#
#   YearsSinceLastPromotion  YearsWithCurrManager       Age_group
# 0                       0                     5    (39.0, 49.5]
# 1                       1                     7    (39.0, 49.5]
# 2                       0                     0    (28.5, 39.0]
# 3                       3                     0    (28.5, 39.0]
# 4                       2                     2  (17.958, 28.5]
#
# [5 rows x 36 columns]

# %%
# Calculate how many unique combinations are for Age and Department
hr.groupby(['Age_group','Department']).size().reset_index(name='Count')
# Out:
#          Age_group              Department  Count
# 0   (17.958, 28.5]         Human Resources     10
# 1   (17.958, 28.5]  Research & Development    171
# 2   (17.958, 28.5]                   Sales     77
# 3     (28.5, 39.0]         Human Resources     28
# 4     (28.5, 39.0]  Research & Development    443
# 5     (28.5, 39.0]                   Sales    219
# 6     (39.0, 49.5]         Human Resources     17
# 7     (39.0, 49.5]  Research & Development    230
# 8     (39.0, 49.5]                   Sales    102
# 9     (49.5, 60.0]         Human Resources      8
# 10    (49.5, 60.0]  Research & Development    117
# 11    (49.5, 60.0]                   Sales     48

# %%
# Set k to be 2, for a 2-anonymous dataset
k = 2

# Calculate how many unique combinations are for Age and Department
df_count = hr.groupby(['Age_group','Department']).size().reset_index(name='Count')
# Out:
#          Age_group              Department  Count
# 0   (17.958, 28.5]         Human Resources     10
# 1   (17.958, 28.5]  Research & Development    171
# 2   (17.958, 28.5]                   Sales     77
# 3     (28.5, 39.0]         Human Resources     28
# 4     (28.5, 39.0]  Research & Development    443
# 5     (28.5, 39.0]                   Sales    219
# 6     (39.0, 49.5]         Human Resources     17
# 7     (39.0, 49.5]  Research & Development    230
# 8     (39.0, 49.5]                   Sales    102
# 9     (49.5, 60.0]         Human Resources      8
# 10    (49.5, 60.0]  Research & Development    117
# 11    (49.5, 60.0]                   Sales     48

# %%
# Filter the rows that have count less than k
df_count[df_count['Count'] < k]
# Out:
# Empty DataFrame
# Columns: [Age_group, Department, Count]
# Index: []

# %%
##---------------customer status dataset------------------


Customer = pd.read_csv('Mall_Customers.csv')
df2 = pd.DataFrame(Customer)
# Explore dataset
Customer.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
#
#    Unnamed: 5 Nationality
# 0         NaN    ukranian
# 1         NaN     russian
# 2         NaN  belarusian
# 3         NaN     mexican
# 4         NaN   colombian

# %%
##---------------Exploring the dataset--------------------

# Set k value to 4
k = 4
# Calculate how many unique combinations are for nationality and gender
df_count = df2.groupby(['Nationality','Gender']).size().reset_index(name='Count')

# Filter the rows that have a count value less than k
df_count[df_count['Count'] < k]
# Out:
# Empty DataFrame
# Columns: [Nationality, Gender, Count]
# Index: []

# %%
##---------Data generalization with hierarchies-----------
# See the combination counts
df2['Gender'].value_counts()
# Out:
# Female    112
# Male       88
# Name: Gender, dtype: int64

# %%
# Create hierarchies for origin countries
hierarchies = {'Europe': ['ukranian','russian','belarusian'],
               'America':['mexican','colombian','cuban'],
               'Asia': ['taiwanese','korean','chinese'],
               'Africa': ['ethiopian','liberian']}

# %%
# Creating hierachy father for each contry
origin_hierarchy = {}
for (key, countries) in hierarchies.items():
    for country in countries:
      origin_hierarchy[country] = key
origin_hierarchy
# Out:
# {'ukranian': 'Europe',
#  'russian': 'Europe',
#  'belarusian': 'Europe',
#  'mexican': 'America',
#  'colombian': 'America',
#  'cuban': 'America',
#  'taiwanese': 'Asia',
#  'korean': 'Asia',
#  'chinese': 'Asia',
#  'ethiopian': 'Africa',
#  'liberian': 'Africa'}

# %%
# Apply origin_hierarchy hierarchy generalization to Nationality
df2['Nationality_generalized'] = df2['Nationality'].map(origin_hierarchy)

# Explore resulting dataset
df2.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
#
#    Unnamed: 5 Nationality Nationality_generalized
# 0         NaN    ukranian                  Europe
# 1         NaN     russian                  Europe
# 2         NaN  belarusian                  Europe
# 3         NaN     mexican                 America
# 4         NaN   colombian                 America

# %%
# Calculate how many unique combinations are for Nationality_generalized and Gender
df_count = df2.groupby(['Nationality_generalized','Gender']).size().reset_index(name='Count')

# Filter the combinations that appear less than k times
df_count[df_count['Count'] < k]
df_count
# Out:
#   Nationality_generalized  Gender  Count
# 0                  Africa  Female     16
# 1                  Africa    Male     18
# 2                 America  Female     31
# 3                 America    Male     26
# 4                    Asia  Female     29
# 5                    Asia    Male     25
# 6                  Europe  Female     36
# 7                  Europe    Male     19
